# %%
import os
import pandas as pd
import plotly.graph_objs as go

# %%
# ram_sizes = [1, 2, 4, 8, 12, 16]
ram_sizes = [1]
mig_methods = ['Vanilla', 'XBZRLE', 'Compress', 'HBFDP_SHA1','HBFDP_MD5', 'HBFDP_Murmur3', 'XBZRLE_HBFDP_SHA1', 'XBZRLE_HBFDP_MD5', 'XBZRLE_HBFDP_Murmur3', 'Compress_HBFDP_SHA1', 'Compress_HBFDP_MD5', 'Compress_HBFDP_Murmur3']

# %%
def mig_time_plot(plot_column="Total-Time", y_title="Total Migration Time (s)", workload="Sysbench"):
    mig_data = {}
    for mig_method in mig_methods:
        mig_data[mig_method] = {"data": [], "deviation": []}
        for ram_size in ram_sizes:
            ram_size_mb = str(ram_size*1024)
            if os.path.exists(f'./data/{mig_method}/{workload}/{ram_size_mb}.csv'):
                data = pd.read_csv(f'./data/{mig_method}/{workload}/{ram_size_mb}.csv')
                filtered_data = data[data['Outlier'] != 'Yes']
                if plot_column == "Total-Time" or plot_column == "Downtime":
                    mig_data[mig_method]["data"].append(filtered_data[plot_column].mean()/1000)
                    mig_data[mig_method]["deviation"].append(filtered_data[plot_column].std()/1000)
                else:
                    mig_data[mig_method]["data"].append(filtered_data[plot_column].mean())
                    mig_data[mig_method]["deviation"].append(filtered_data[plot_column].std())
    
    data = pd.DataFrame({'RAM Size (GB)': [ str(ram_size) for ram_size in ram_sizes]})
    
    count=1
    for mig_method in mig_methods:
        if len(mig_data[mig_method]["data"]) == 1:
            data.insert(column=mig_method, value=mig_data[mig_method]["data"], loc=count)  
            count += 1
    
    # print(data)

    layout = go.Layout(
                    xaxis=dict(title='RAM Size (GB)'),
                    yaxis=dict(title=y_title),
                    barmode='group',
                    template='simple_white'
                    )
    
    trace = []
    
    for mig_method in mig_methods:
        name = ""
        for word in mig_method.split("_"):
            name = f'{name} {word}'
            
        if len(mig_data[mig_method]["data"]) == 1:
            trace.append(go.Bar(x=data['RAM Size (GB)'], y=data[mig_method], name=f'{name} Pre-Copy', error_y=dict(type='data', array=mig_data[mig_method]["deviation"])))

    fig = go.Figure(data=trace, layout=layout)

    fig.update_layout(
        width=777,  # 0.45 text width
        height=700,
        font=dict(family="Arial", size=17.2, color="black"),
        margin=dict(t=15, r=5, l=70, b=45, autoexpand=True),
        yaxis_title_standoff=10,
        xaxis_title_standoff=8,
        legend=dict(
            orientation="h",
            yanchor="bottom",
            # Align center
            y=-0.5,
        ),
    )
    fig.write_image(f"./RAM-Size-vs-{plot_column}.{workload}.png",scale=4, width=777, height=700)

    fig.show()

# %%
mig_time_plot("Total-Time", "Total Migration Time (s)", "Memcached")
# Out:
# <div>                            <div id="84643765-b950-4990-9fce-25ea12f9a3a5" class="plotly-graph-div" style="height:700px; width:777px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("84643765-b950-4990-9fce-25ea12f9a3a5")) {                    Plotly.newPlot(                        "84643765-b950-4990-9fce-25ea12f9a3a5",                        [{"error_y":{"array":[0.45633627951325545],"type":"data"},"name":" Vanilla Pre-Copy","x":["1"],"y":[11.2524],"type":"bar"},{"error_y":{"array":[2.9761511554354896],"type":"data"},"name":" XBZRLE Pre-Copy","x":["1"],"y":[12.3072],"type":"bar"},{"error_y":{"array":[0.5465688428734299],"type":"data"},"name":" Compress Pre-Copy","x":["1"],"y":[6.638],"type":"bar"},{"error_y":{"array":[0.3954664334681263],"type":"data"},"name":" HBFDP SHA1 Pre-Copy","x":["1"],"y":[10.3952],"type":"bar"},{"error_y":{"array":[0.7661251203295713],"type":"data"},"name":" HBFDP MD5 Pre-Copy","x":["1"],"y":[9.946200000000001],"type":"bar"},{"error_y":{"array":[0.46795117266655073],"type":"data"},"name":" HBFDP Murmur3 Pre-Copy","x":["1"],"y":[10.6046],"type":"bar"},{"error_y":{"array":[2.4283069616504416],"type":"data"},"name":" XBZRLE HBFDP SHA1 Pre-Copy","x":["1"],"y":[13.5358],"type":"bar"},{"error_y":{"array":[2.1868570369367997],"type":"data"},"name":" XBZRLE HBFDP MD5 Pre-Copy","x":["1"],"y":[13.6582],"type":"bar"},{"error_y":{"array":[1.679772216700824],"type":"data"},"name":" XBZRLE HBFDP Murmur3 Pre-Copy","x":["1"],"y":[12.7552],"type":"bar"},{"error_y":{"array":[2.2695488538473896],"type":"data"},"name":" Compress HBFDP SHA1 Pre-Copy","x":["1"],"y":[7.27],"type":"bar"},{"error_y":{"array":[0.14013671895688154],"type":"data"},"name":" Compress HBFDP MD5 Pre-Copy","x":["1"],"y":[6.0886000000000005],"type":"bar"},{"error_y":{"array":[2.1057464234802823],"type":"data"},"name":" Compress HBFDP Murmur3 Pre-Copy","x":["1"],"y":[7.576],"type":"bar"}],                        {"barmode":"group","template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222 ...
