# %%
import os
import pandas as pd
import plotly.graph_objs as go

# %%
# ram_sizes = [1, 2, 4, 8, 12, 16]
ram_sizes = [16]
mig_methods = ['Vanilla', 'XBZRLE', 'HBFDP_SHA1', 'XBZRLE_HBFDP_SHA1','HBFDP_MD5', 'XBZRLE_HBFDP_MD5', 'HBFDP_Murmur3']

# %%
def mig_time_plot(plot_column="Total-Time", y_title="Total Migration Time (s)", workload="Sysbench"):
    mig_data = {}
    for mig_method in mig_methods:
        mig_data[mig_method] = {"data": [], "deviation": []}
        for ram_size in ram_sizes:
            ram_size_mb = str(ram_size*1024)
            if os.path.exists(f'./data/{mig_method}/{workload}/{ram_size_mb}.csv'):
                data = pd.read_csv(f'./data/{mig_method}/{workload}/{ram_size_mb}.csv')
                filtered_data = data[data['Outlier'] != 'Yes']
                if plot_column == "Total-Time" or plot_column == "Downtime":
                    mig_data[mig_method]["data"].append(filtered_data[plot_column].mean()/1000)
                    mig_data[mig_method]["deviation"].append(filtered_data[plot_column].std()/1000)
                else:
                    mig_data[mig_method]["data"].append(filtered_data[plot_column].mean())
                    mig_data[mig_method]["deviation"].append(filtered_data[plot_column].std())
    
    data = pd.DataFrame({'RAM Size (GB)': [ str(ram_size) for ram_size in ram_sizes]})
    
    count=1
    for mig_method in mig_methods:
        if len(mig_data[mig_method]["data"]) == 1:
            data.insert(column=mig_method, value=mig_data[mig_method]["data"], loc=count)  
            count += 1
    
    print(data)

    layout = go.Layout(
                    xaxis=dict(title='RAM Size (GB)'),
                    yaxis=dict(title=y_title),
                    barmode='group',
                    template='simple_white'
                    )
    
    trace = []
    
    for mig_method in mig_methods:
        name = ""
        for word in mig_method.split("_"):
            name = f'{name} {word}'
            
        if len(mig_data[mig_method]["data"]) == 1:
            trace.append(go.Bar(x=data['RAM Size (GB)'], y=data[mig_method], name=f'{name} Pre-Copy', error_y=dict(type='data', array=mig_data[mig_method]["deviation"])))

    fig = go.Figure(data=trace, layout=layout)

    fig.update_layout(
        width=777,  # 0.45 text width
        height=600,
        font=dict(family="Arial", size=17.2, color="black"),
        margin=dict(t=15, r=5, l=70, b=45, autoexpand=True),
        yaxis_title_standoff=10,
        xaxis_title_standoff=8,
        legend=dict(
            orientation="h",
            yanchor="bottom",
            # Align center
            y=-0.5,
        ),
    )
    fig.write_image(f"./RAM-Size-vs-{plot_column}.{workload}.png",scale=4, width=777, height=600)

    fig.show()

# %%
mig_time_plot("Total-Time", "Total Migration Time (s)", "Memcached")
# Out:
#   RAM Size (GB)    Vanilla  XBZRLE  HBFDP_SHA1  XBZRLE_HBFDP_SHA1  HBFDP_MD5  \
# 0            16  74.800667  69.335   66.590333             73.536  67.576667
#
#    HBFDP_Murmur3
# 0        70.9086
# <div>                            <div id="73ab271a-de9a-4e73-929f-3ae326cb6608" class="plotly-graph-div" style="height:600px; width:777px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("73ab271a-de9a-4e73-929f-3ae326cb6608")) {                    Plotly.newPlot(                        "73ab271a-de9a-4e73-929f-3ae326cb6608",                        [{"error_y":{"array":[2.2939752250914425],"type":"data"},"name":" Vanilla Pre-Copy","x":["16"],"y":[74.80066666666667],"type":"bar"},{"error_y":{"array":[1.3173955366555636],"type":"data"},"name":" XBZRLE Pre-Copy","x":["16"],"y":[69.335],"type":"bar"},{"error_y":{"array":[1.0658810127464196],"type":"data"},"name":" HBFDP SHA1 Pre-Copy","x":["16"],"y":[66.59033333333333],"type":"bar"},{"error_y":{"array":[1.299894995759273],"type":"data"},"name":" XBZRLE HBFDP SHA1 Pre-Copy","x":["16"],"y":[73.536],"type":"bar"},{"error_y":{"array":[0.5156203383627661],"type":"data"},"name":" HBFDP MD5 Pre-Copy","x":["16"],"y":[67.57666666666667],"type":"bar"},{"error_y":{"array":[1.8043065981146331],"type":"data"},"name":" HBFDP Murmur3 Pre-Copy","x":["16"],"y":[70.9086],"type":"bar"}],                        {"barmode":"group","template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0," ...
